# %% [markdown]
# **Data transformations**

# %% [markdown]
# - Generally data has 3 types of distributions
#   -
# Normal distributio
#   -
# Postive Skew
#   - d
# Negative Sked
#
# - ed
# All the maths concepts developed by assumption as Data follows No mal
# distrib
# - tion
# Data skew happens because of many reasons, in that one reason is
# - liers
# Once we perform the outlier analysis then we can apply transformation eho s , if
# the data does not follows n
# - rmality
# We have some transformation methods mentiw
#      - ed below
# Log Tran
#      - formation
# Exponential Tra
#      - sformation
# Reciprocal Tr
#      - nsformation
# Square root T
#      - ansformation
# Power TransformationTransformation

# %% [markdown]
# $step-1$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $step-2$

# %% [markdown]
# **Read the data**

# %%
exp_data= np.random.exponential(size=10000)
exp_data
# Out:
# array([2.55585306, 0.37559166, 0.07969618, ..., 0.216418  , 0.32784526,
#        1.47389598])

# %% [markdown]
# $step-3$

# %% [markdown]
# **plot the data**

# %%
plt.hist(exp_data,bins=20,label='Exponential')
plt.show()

# %%
norm_data= np.random.normal(size=10000)
plt.hist(norm_data,bins=20,label='Exponential')
plt.show()

# %% [markdown]
# **Goal***

# %% [markdown]
# **Convert exp_data to Normal distribution**

# %% [markdown]
# bins= interval

# %% [markdown]
# $step-4$

# %% [markdown]
# **Log transformation**
# - Log transformation means performing logarithm operations on origianl data
# - It is an approach to convert into Noraml distribution
# - Log means natural logarithm base=e

# %%
x=2
np.log(x)
# Out:
# 0.6931471805599453

# %%
log_data=np.log(exp_data)
log_data
# Out:
# array([ 0.93838605, -0.97925275, -2.52953359, ..., -1.53054354,
#        -1.11521354,  0.38790922])

# %%
plt.hist(log_data,bins=20,label='Logarithm')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=30,label='Logaritham')
plt.legend()
plt.show()

# %% [markdown]
# **Reciprocal Transformations**
# - Reciprocal will fail when values are low
# - For examples x=0 then 1/0 fail

# %%
x=2
1/x
# Out:
# 0.5

# %%
resiprocal_data=np.reciprocal(exp_data)
plt.hist(resiprocal_data,bins=20,label="Reciprocal")
plt.show()

# %% [markdown]
# **Square root transformation**

# %%
square_root_data = np.sqrt(exp_data)
plt.hist(square_root_data, bins=20, label="Square Root Data")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,3))
log_data = np.log(exp_data)
plt.subplot(1,3,1).hist(exp_data,bins=20,label='Exponential')
plt.legend()
log_data = np.log(exp_data)
plt.subplot(1,3,2).hist(log_data,bins=20,label='Logarithm')
plt.legend()
square_data = np.sqrt(exp_data)
plt.subplot(1,3,3).hist(square_data,bins=20,label='Square')
plt.legend()
plt.show()

# %% [markdown]
# **Power Transformation**
# - Box cox
# - ye-jhonson
# - It is under sklearn preprocessing

# %%
import numpy as np
from sklearn.preprocessing import PowerTransformer
# save
# apply fit transform

# %%
from sklearn.preprocessing import PowerTransformer
power = PowerTransformer(method='yeo-johnson')
exp_data1=exp_data.reshape(-1,1)
data_trans = power.fit_transform(exp_data1)
plt.hist(data_trans)
# Out:
# (array([1015., 1100., 1276., 1364., 1249., 1313., 1164.,  855.,  504.,
#          160.]),
#  array([-1.77851791, -1.36178526, -0.9450526 , -0.52831995, -0.11158729,
#          0.30514536,  0.72187802,  1.13861067,  1.55534332,  1.97207598,
#          2.38880863]),
#  <BarContainer object of 10 artists>)

# %%
exp_data
# Out:
# array([2.55585306, 0.37559166, 0.07969618, ..., 0.216418  , 0.32784526,
#        1.47389598])

# %%
exp_data.reshape(-1,1)
# Out:
# array([[2.55585306],
#        [0.37559166],
#        [0.07969618],
#        ...,
#        [0.216418  ],
#        [0.32784526],
#        [1.47389598]])

# %%
# Apply box cox share the output

# %%
import numpy as np
from scipy import stats

# %% [markdown]
# eda we use python to order the file data to an read and edit model form
